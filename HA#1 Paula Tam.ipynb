# %%
#CSC620
#Paula Abigail Tam <921850992>
#HA1
#Due: August 31, 2022

from nltk.chat.util import Chat, reflections

pairs = (
    (
        r"[iI] don\'?t understand (.*)",
        (
            "I can send you some resources so you can better understand %1",
        ),
    ),
    (
        r"[bB]ecause I\'?m having (.*) in my class",
        (
            "Do you think you need a tutor?",
        ),
    ),
    (
        r"(.*) I need a tutor",
        (
            "I can send you some info about some tutors. These should help.",
        ),
    ),
    (
        r"[iI]\'?m worried about (.*)",
        (
            "Why are you worried about %1?",
            "Do you think you require help from a tutor?",
        ),
    ),
    (
        r"[iI]t was (.*)",
        (
            "Why do you say that they were %1?",
            "How are you doing grade wise?",
            
        ),
    ),
    (
        r"(.*) grades are (.*)",
        (
            "Why do you think your grades are %2?",
            "Why would your grades be %2?",
        ),
    ),
    (
        r"[tT]hank you",
        (
            "It was no problem, did you want to talk about anything else?",
        ),
    ),
    (
        r"[yY]es",
        (
            "Okay. What can I help you with?",
        ),
    ),
    (
        r"[nN]o",
        (
            "Okay. Thank you for talking with me today! Type 'quit' to exit.",
        ),
    ),
    (
        r"[qQ]uit",
        (
            "Good-bye.",
            "Have a good day!",
        ),
    ),
    (
        r"(.*)",
        (
            "Please tell me more.",
            "Can you elaborate on that?",
        ),
    ),
)

eliza_chatbot = Chat(pairs, reflections)


def eliza_chat():
    print("Listener\n---------")
    print("Talk to the program by typing in plain English, using normal upper-")
    print('and lower-case letters and punctuation.  Enter "quit" when done.')
    print("=" * 72)
    print("Hello. How was your class today?")

    eliza_chatbot.converse()



def demo():
    eliza_chat()



if __name__ == "__main__":
    demo()
# Out:
# Listener
# ---------
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ========================================================================
# Hello. How was your class today?
# >fine
# Can you elaborate on that?
# >it was okay
# How are you doing grade wise?
# >my grades are average
# Why would your grades be average?
# >because im having some trouble in my class
# Do you think you need a tutor?
# >yeah i need a tutor
# I can send you some info about some tutors. These should help.
# >thank you
# It was no problem, did you want to talk about anything else?
# >yes
# Okay. What can I help you with?
# >im worried about the upcoming test
# Why are you worried about the upcoming test?
# >i dont understand the material
# I can send you some resources so you can better understand the material
# >thank you
# It was no problem, did you want to talk about anything else?
# >no
# Okay. Thank you for talking with me today! Type 'quit' to exit.
# >quit
# Good-bye.
